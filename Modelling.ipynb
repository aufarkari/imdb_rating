# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-Library" data-toc-modified-id="Importing-Library-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing Library</a></span></li><li><span><a href="#Reading-Data" data-toc-modified-id="Reading-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Reading Data</a></span></li></ul></div>

# %% [markdown]
# ## Importing Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading Data

# %%
title_ratings_df = pd.read_csv('data/title.ratings.tsv.gz', sep = '\t')

title_ratings_df = title_ratings_df.replace("\\N",np.nan)

# %%
title_akas_df = pd.read_csv('data/title.akas.tsv.gz', sep = '\t')

mask = title_akas_df['titleId'].isin(title_ratings_df['tconst'])

title_akas_df = title_akas_df[mask]

title_akas_df = title_akas_df.replace("\\N",np.nan)

title_akas_df.shape
# Out:
# C:\Users\karteuku\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (3708249, 8)

# %%
title_akas_summary = pd.pivot_table(title_akas_df, index= 'titleId', 
                                    columns = ['title', 'ordering', 'region', 'types', 'language'], 
                                    aggfunc = lambda x: len(x.unique())
                                    )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-4eaf0e7933da> in <module>
# ----> 1 title_akas_summary = pd.pivot_table(title_akas_df, index= 'titleId',
#       2                                     columns = ['title', 'ordering', 'region', 'types', 'language'],
#       3                                     aggfunc = lambda x: len(x.unique())
#       4                                     )
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     144             else:
#     145                 to_unstack.append(name)
# --> 146         table = agged.unstack(to_unstack)
#     147
#     148     if not dropna:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    7350         from pandas.core.reshape.reshape import unstack
#    7351
# -> 7352         result = unstack(self, level, fill_value)
#    7353
#    7354         return result.__finalize__(self, method="unstack")
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     405             # _unstack_multiple only handles MultiIndexes,
#     406             # and isn't needed for a single level
# --> 407             return _unstack_multiple(obj, level, fill_value=fill_value)
#     408         else:
#     409             level = level[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _unstack_multiple(data, clocs, fill_value)
#     374         dummy.index = dummy_index
#     375
# --> 376         unstacked = dummy.unstack("__placeholder__", fill_value=fill_value)
#     377         if isinstance(unstacked, Series):
#     378             unstcols = unstacked.index
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    7350         from pandas.core.reshape.reshape import unstack
#    7351
# -> 7352         result = unstack(self, level, fill_value)
#    7353
#    7354         return result.__finalize__(self, method="unstack")
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     415     if isinstance(obj, DataFrame):
#     416         if isinstance(obj.index, MultiIndex):
# --> 417             return _unstack_frame(obj, level, fill_value=fill_value)
#     418         else:
#     419             return obj.T.stack(dropna=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _unstack_frame(obj, level, fill_value)
#     442         return obj._constructor(mgr)
#     443     else:
# --> 444         return _Unstacker(
#     445             obj.index, level=level, constructor=obj._constructor
#     446         ).get_result(obj._values, value_columns=obj.columns, fill_value=fill_value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     116             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     117
# --> 118         self._make_selectors()
#     119
#     120     @cache_readonly
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     162         selector = self.sorted_labels[-1] + stride * comp_index + self.lift
#     163         mask = np.zeros(np.prod(self.full_shape), dtype=bool)
# --> 164         mask.put(selector, True)
#     165
#     166         if mask.sum() < len(self.index):
#
# IndexError: index 2145938126 is out of bounds for axis 0 with size 2145811160

# %%
title_basics_df = pd.read_csv('data/title.basics.tsv.gz', sep = '\t')

title_basics_df
# Out:
# C:\Users\karteuku\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8538932  tt9916848  tvEpisode              Episode #3.17
# 8538933  tt9916850  tvEpisode              Episode #3.19
# 8538934  tt9916852  tvEpisode              Episode #3.20
# 8538935  tt9916856      short                   The Wind
# 8538936  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 8538932              Episode #3.17       0      2010      \N             \N
# 8538933              Episode #3.19       0      2010      \N             \N
# 8538934              Episode #3.20       0      2010      \N             \N
# 8538935                   The Wind       0      2015      \N             27
# 8538936  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 8538932         Action,Drama,Family
# 8538933         Action,Drama,Family
# 8538934         Action,Drama,Family
# 8538935                       Short
# 8538936  Adventure,Animation,Comedy
#
# [8538937 rows x 9 columns]

# %%
title_crew_df = pd.read_csv('data/title.crew.tsv.gz', sep = '\t')

title_crew_df
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 8538932  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8538933  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8538934  tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 8538935  tt9916856           nm10538645                      nm6951431
# 8538936  tt9916880            nm0996406            nm1482639,nm2586970
#
# [8538937 rows x 3 columns]

# %%
title_episode_df = pd.read_csv('data/title.episode.tsv.gz', sep = '\t')

title_episode_df
# Out:
#             tconst parentTconst seasonNumber episodeNumber
# 0        tt0020666   tt15180956            1             2
# 1        tt0020829   tt15180956            1             1
# 2        tt0021166   tt15180956            1             3
# 3        tt0021612   tt15180956            2             2
# 4        tt0021655   tt15180956            2             5
# ...            ...          ...          ...           ...
# 6369074  tt9916846    tt1289683            3            18
# 6369075  tt9916848    tt1289683            3            17
# 6369076  tt9916850    tt1289683            3            19
# 6369077  tt9916852    tt1289683            3            20
# 6369078  tt9916880    tt0985991            4             2
#
# [6369079 rows x 4 columns]

# %%
title_principals_df = pd.read_csv('data/title.principals.tsv.gz', sep = '\t')

title_principals_df
# Out:
#              tconst  ordering      nconst         category  \
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 48009030  tt9916880         4  nm10535738          actress
# 48009031  tt9916880         5   nm0996406         director
# 48009032  tt9916880         6   nm1482639           writer
# 48009033  tt9916880         7   nm2586970           writer
# 48009034  tt9916880         8   nm1594058         producer
#
#                               job        characters
# 0                              \N          ["Self"]
# 1                              \N                \N
# 2         director of photography                \N
# 3                              \N                \N
# 4                              \N                \N
# ...                           ...               ...
# 48009030                       \N  ["Horrid Henry"]
# 48009031       principal director                \N
# 48009032                       \N                \N
# 48009033                    books                \N
# 48009034                 producer                \N
#
# [48009035 rows x 6 columns]

# %%
title_ratings_df = pd.read_csv('data/title.ratings.tsv.gz', sep = '\t')

title_ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1846
# 1        tt0000002            6.0       236
# 2        tt0000003            6.5      1606
# 3        tt0000004            6.0       153
# 4        tt0000005            6.2      2429
# ...            ...            ...       ...
# 1197149  tt9916682            5.6         5
# 1197150  tt9916690            6.6         5
# 1197151  tt9916720            5.5       158
# 1197152  tt9916766            6.7        18
# 1197153  tt9916778            7.3        33
#
# [1197154 rows x 3 columns]

# %%
data = title_ratings_df.copy()

# %%
title_akas_df.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
mask = title_akas_df['titleId'].isin(title_ratings_df['tconst'])

title_akas_df= title_akas_df[mask]

# %%
#title_akas_summary = pd.pivot_table(title_akas_df, index= 'titleId', 
#                                    columns = ['title', 'ordering', 'region', 'types', 'language'], 
#                                    aggfunc = lambda x: len(x.unique())
#                                    )
